# %%
import pandas as pd

# %%
df_train = pd.read_csv('X_train.csv', nrows=100000)
df_test = pd.read_csv('X_test.csv', nrows=100000)
# Out:
# /tmp/ipykernel_13878/1962512753.py:1: DtypeWarning: Columns (1,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_train = pd.read_csv('X_train.csv', nrows=100000)
# /tmp/ipykernel_13878/1962512753.py:2: DtypeWarning: Columns (1,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_test = pd.read_csv('X_test.csv', nrows=100000)

# %%
var = "piezo_groundwater_level_category"

# Splitting into X and y variables
X_train = df_train.drop(var, axis=1)
y_train = df_train[var]

y_train.unique()
# Out:
# array(['High', 'Very High', 'Very Low', 'Low', 'Average'], dtype=object)

# %%
print(X_train.head())
# Out:
#    row_index piezo_station_department_code      piezo_station_update_date  \
# 0          0                            01  Sun Jul 14 13:00:02 CEST 2024
# 1          1                            01  Sun Jul 14 13:00:02 CEST 2024
# 2          2                            01  Sun Jul 14 13:00:02 CEST 2024
# 3          3                            01  Sun Jul 14 13:00:02 CEST 2024
# 4          4                            01  Sun Jul 14 13:00:02 CEST 2024
#
#    piezo_station_investigation_depth piezo_station_department_name  \
# 0                              20.00                           Ain
# 1                              35.60                           Ain
# 2                              35.22                           Ain
# 3                              34.20                           Ain
# 4                              37.30                           Ain
#
#   piezo_station_commune_code_insee  \
# 0                            01073
# 1                            01363
# 2                            01244
# 3                            01288
# 4                            01422
#
#                               piezo_station_pe_label  \
# 0  PIEZOMETRE - MARAIS DE LAVOURS (CEYZERIEU - BR...
# 1  PIEZOMETRE - GRAVIERE (ST-JEAN-LE-VIEUX - BRGM...
# 2  PIEZOMETRE - BORD AUTOROUTE (MEXIMIEUX - BRGM ...
# 3         PIEZOMETRE - GRENY (PERON - BRGM 01) - BSH
# 4          FORAGE - ENCLOS (TOSSIAT - BRGM 01) - BSH
#
#   piezo_station_bdlisa_codes  piezo_station_altitude piezo_station_bss_code  \
# 0                ['712AH37']                  232.00       07004X0046/D6-20
# 1                ['712GB05']                  247.25          06754X0077/F1
# 2                ['040AJ43']                  218.77      06993X0226/MEXI_2
# 3     ['516AA00', '516AF00']                  499.85          06533X0070/F2
# 4                ['507AB00']                  260.00          06518X0026/P2
#
#    ... prelev_volume_obtention_mode_label_2  prelev_longitude_2  \
# 0  ...                     Mesure indirecte            5.698947
# 1  ...                     Mesure indirecte            5.464933
# 2  ...                     Mesure indirecte            5.085060
# 3  ...                     Mesure indirecte            5.802841
# 4  ...                     Mesure indirecte            5.377265
#
#    prelev_latitude_2 prelev_commune_code_insee_2 prelev_other_volume_sum  \
# 0          45.725106                      1454.0            1.793055e+09
# 1          46.210734                      1051.0            1.085125e+09
# 2          45.812828                     69266.0            3.810492e+08
# 3          46.366049                     39286.0            3.800911e+08
# 4          46.080989                      1273.0            1.966631e+07
#
#   insee_%_agri insee_pop_commune insee_med_living_level insee_%_ind  \
# 0         11.8             992.0                  25250         2.9
# 1          0.6            1786.0                  24660        44.5
# 2            0            8085.0                  24890         8.4
# 3          1.5            2838.0                  39700         2.4
# 4          0.2            1352.0                  26180        21.5
#
#    insee_%_const
# 0           16.2
# 1             11
# 2            7.8
# 3            5.2
# 4            9.8
#
# [5 rows x 135 columns]

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99000 entries, 0 to 98999
# Columns: 135 entries, row_index to insee_%_const
# dtypes: float64(90), int64(6), object(39)
# memory usage: 102.0+ MB

# %%
X_train.describe()
# Out:
#            row_index  piezo_station_investigation_depth  \
# count   99000.000000                       92950.000000
# mean    52040.730677                          86.124995
# std     30071.093722                         246.620822
# min         0.000000                           0.000000
# 25%     25930.750000                          16.470000
# 50%     52000.500000                          38.000000
# 75%     78030.250000                          80.000000
# max    104042.000000                        5233.400000
#
#        piezo_station_altitude  piezo_station_longitude  \
# count            99000.000000             99000.000000
# mean               146.243329                 2.221069
# std                190.882599                 2.720432
# min               -999.000000                -4.657129
# 25%                 41.230000                -0.104026
# 50%                107.070000                 1.899121
# 75%                184.695000                 4.203498
# max               2150.000000                 9.519890
#
#        piezo_station_latitude  piezo_continuity_code  piezo_producer_code  \
# count            99000.000000           99000.000000         9.340400e+04
# mean                46.428650               1.999101         5.523904e+12
# std                  2.174574               0.029970         1.121925e+13
# min                 41.399732               1.000000         1.960000e+02
# 25%                 44.499602               2.000000         2.910000e+02
# 50%                 46.401557               2.000000         3.000000e+02
# 75%                 48.219799               2.000000         1.219000e+03
# max                 50.971087               2.000000         4.049439e+13
#
#            meteo_id  meteo_latitude  meteo_longitude  ...  prelev_volume_1  \
# count  9.900000e+04    99000.000000     99000.000000  ...     9.795400e+04
# mean   3.741482e+07        2.195620        46.434289  ...     8.686558e+08
# std    2.083321e+07        2.680141         2.138581  ...     4.407440e+09
# min    1.027003e+06       -4.664167        42.384667  ...     0.000000e+00
# 25%    1.912100e+07       -0.152000        44.534667  ...     9.140210e+05
# 50%    3.420900e+07        1.903167        46.417000  ...     2.869521e+06
# 75%    5.246900e+07        4.192000        48.216333  ...     2.279200e+07
# max    9.558000e+07        8.145500        50.833833  ...     3.508028e+10
#
#        prelev_longitude_1  prelev_latitude_1  prelev_commune_code_insee_1  \
# count        97954.000000       97954.000000                 97954.000000
# mean             2.135226          46.475390                 44860.268912
# std              2.642186           2.145542                 24661.174358
# min             -4.487265          42.407792                  1051.000000
# 25%             -0.200520          44.560612                 25479.000000
# 50%              1.821023          46.529573                 40332.000000
# 75%              4.071172          48.250904                 66205.000000
# max              8.087510          50.948383                 95170.000000
#
#        prelev_volume_2  prelev_longitude_2  prelev_latitude_2  \
# count     9.791500e+04        97915.000000       97915.000000
# mean      3.533575e+08            2.141104          46.469894
# std       2.447046e+09            2.641213           2.144821
# min       1.541000e+03           -4.731051          42.435492
# 25%       6.918670e+05           -0.149475          44.572622
# 50%       1.591235e+06            1.828238          46.490266
# 75%       8.947526e+06            4.071172          48.256778
# max       3.311219e+10            8.087510          50.864884
#
#        prelev_commune_code_insee_2  prelev_other_volume_sum  insee_pop_commune
# count                 97915.000000             9.900000e+04       98041.000000
# mean                  45117.213808             2.712203e+08        7086.830775
# std                   24806.548189             1.528207e+09       32585.938970
# min                    1027.000000             0.000000e+00           6.000000
# 25%                   25221.000000             1.101470e+07         482.000000
# 50%                   40320.000000             2.122902e+07        1238.000000
# 75%                   67482.000000             5.280639e+07        3752.000000
# max                   94054.000000             2.566101e+10      873076.000000
#
# [8 rows x 96 columns]

# %%
X_train.isnull().sum()
# Out:
# row_index                               0
# piezo_station_department_code           0
# piezo_station_update_date               0
# piezo_station_investigation_depth    6050
# piezo_station_department_name           0
#                                      ...
# insee_%_agri                          959
# insee_pop_commune                     959
# insee_med_living_level                959
# insee_%_ind                           959
# insee_%_const                         959
# Length: 135, dtype: int64
