# %% [markdown]
# # Load data

# %%
from pandas import DataFrame, read_csv

def load_data(
        data_file: str,
        n_rows: int | None = None,
) -> DataFrame:
    return read_csv(data_file, index_col='row_index', nrows=n_rows)

# %%
import pandas as pd

#train_data = file_manager.load_training_data()

# TODO
train_file = 'X_train.csv'
test_file = 'X_test.csv'
n_rows = 100_000

test_data = load_data(test_file)
tiny_train_data = load_data(train_file, n_rows=n_rows)

# %% [markdown]
# # Split raw data by variable category (piezo, weather, ...)
#
# We are only interested in training data.

# %%
from pandas import DataFrame

# Function to extract variable category
def extract_category(
        df: DataFrame,
        category: str,
) -> DataFrame:
    return df[df.columns[df.columns.str.startswith(category)]]

# %%
# Example with meteo variables
withdrawal_variables = extract_category(tiny_train_data, 'prelev')
withdrawal_variables.head()
# Out:
#           prelev_structure_code_0  prelev_volume_0    prelev_usage_label_0  \
# row_index
# 0                   OPR0000048924     1.074315e+10  EAU TURBINEE (barrage)
# 1                   OPR0000048937     1.249202e+10  EAU TURBINEE (barrage)
# 2                   OPR0000048937     1.249202e+10  EAU TURBINEE (barrage)
# 3                   OPR0000048929     1.038289e+10  EAU TURBINEE (barrage)
# 4                   OPR0000048934     2.206200e+09  EAU TURBINEE (barrage)
#
#           prelev_volume_obtention_mode_label_0  prelev_longitude_0  \
# row_index
# 0                             Mesure indirecte            5.811394
# 1                             Mesure indirecte            5.405995
# 2                             Mesure indirecte            5.405995
# 3                             Mesure indirecte            5.812855
# 4                             Mesure indirecte            5.421808
#
#            prelev_latitude_0  prelev_commune_code_insee_0  \
# row_index
# ...

# %% [markdown]
# # Withdrawal Information

# %%
withdrawal_variables.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100000 entries, 0 to 105170
# Data columns (total 22 columns):
#  #   Column                                Non-Null Count   Dtype
# ---  ------                                --------------   -----
#  0   prelev_structure_code_0               98927 non-null   object
#  1   prelev_volume_0                       98927 non-null   float64
#  2   prelev_usage_label_0                  98927 non-null   object
#  3   prelev_volume_obtention_mode_label_0  98927 non-null   object
#  4   prelev_longitude_0                    98927 non-null   float64
#  5   prelev_latitude_0                     98927 non-null   float64
#  6   prelev_commune_code_insee_0           98927 non-null   float64
#  7   prelev_structure_code_1               98927 non-null   object
#  8   prelev_volume_1                       98927 non-null   float64
#  9   prelev_usage_label_1                  98927 non-null   object
# ...

# %% [markdown]
# # Withdrawal Histograms

# %%
        import matplotlib.pyplot as plt

        plt.hist(withdrawal_variables["prelev_volume_0"])
        plt.xlabel("Maximum water withdrawal volume")
        plt.show()

# %%
        import matplotlib.pyplot as plt

        plt.hist(withdrawal_variables["prelev_longitude_0"])
        plt.xlabel("Longitude of the water withdrawal facility")
        plt.show()

# %%
        import matplotlib.pyplot as plt

        plt.hist(withdrawal_variables["prelev_latitude_0"])
        plt.xlabel("Latitude of the water withdrawal facility")
        plt.show()

# %%
        import matplotlib.pyplot as plt

        plt.hist(withdrawal_variables["prelev_commune_code_insee_0"])
        plt.xlabel("City/municipality code where the widthdrawal was made")
        plt.show()

# %%
        import matplotlib.pyplot as plt

        plt.hist(withdrawal_variables["prelev_volume_1"])
        plt.xlabel("Maximum water withdrawal volume")
        plt.show()

# %%
        import matplotlib.pyplot as plt

        plt.hist(withdrawal_variables["prelev_longitude_1"])
        plt.xlabel("Longitude of the water withdrawal facility")
        plt.show()

# %%
        import matplotlib.pyplot as plt

        plt.hist(withdrawal_variables["prelev_latitude_1"])
        plt.xlabel("Latitude of the water withdrawal facility")
        plt.show()

# %%
        import matplotlib.pyplot as plt

        plt.hist(withdrawal_variables["prelev_commune_code_insee_1"])
        plt.xlabel("City/municipality code where the widthdrawal was made")
        plt.show()

# %%
        import matplotlib.pyplot as plt

        plt.hist(withdrawal_variables["prelev_volume_2"])
        plt.xlabel("Maximum water withdrawal volume")
        plt.show()

# %%
        import matplotlib.pyplot as plt

        plt.hist(withdrawal_variables["prelev_longitude_2"])
        plt.xlabel("Longitude of the water withdrawal facility")
        plt.show()

# %%
        import matplotlib.pyplot as plt

        plt.hist(withdrawal_variables["prelev_latitude_2"])
        plt.xlabel("Latitude of the water withdrawal facility")
        plt.show()

# %%
        import matplotlib.pyplot as plt

        plt.hist(withdrawal_variables["prelev_commune_code_insee_2"])
        plt.xlabel("City/municipality code where the widthdrawal was made")
        plt.show()

# %%
        import matplotlib.pyplot as plt

        plt.hist(withdrawal_variables["prelev_other_volume_sum"])
        plt.xlabel("Sum of other water widthdrawals")
        plt.show()
